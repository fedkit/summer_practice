# %%
LAMBDA_MAX = 5.71523555422111

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.sparse import load_npz
Z = np.load('Z.npy')
X = np.load('X.npy')
Y = load_npz('Y.npz')
labels = pd.read_csv('labels.csv')
U = np.load('U.npy')
Vt = np.load('Vt.npy')
eigenvalues = np.load('eigenvalues.npy')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report
from sklearn.multioutput import MultiOutputClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1,
    verbose=0
)

catboost = CatBoostClassifier(
    iterations=100,
    random_state=42,
    verbose=0,
    task_type='CPU'
)

logreg = LogisticRegression(
    max_iter=1000,
    random_state=42,
    n_jobs=-1
)


ensemble = VotingClassifier(
    estimators=[
        ('rf', rf),
        ('catboost', catboost),
        ('logreg', logreg)
    ],
    voting='soft'  
)

# %%
model = MultiOutputClassifier(ensemble, n_jobs=-1)

# %%
import numpy as np
import matplotlib.pyplot as plt

accuracies = []
num_components_list = []

for t in np.arange(0.85, 1.21, 0.05):
    lambda_limit = t * LAMBDA_MAX
    significant_mask = eigenvalues > lambda_limit
    significant_eigenvalues = eigenvalues[significant_mask]

    print(f"\n--- Порог: {t:.2f} * lambda_max = {lambda_limit:.4f} ---")
    print(f"Число главных компонент: {len(significant_eigenvalues)}")

    significant_components = Vt[significant_mask]
    Z = Y @ significant_components.T

    X_train, X_test, y_train, y_test = train_test_split(
        Z, 
        labels, 
        test_size=0.2, 
        random_state=42, 
        stratify=labels if len(np.unique(labels)) > 1 else None
    )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = np.mean(y_pred == y_test)
    accuracies.append(accuracy)
    num_components_list.append(len(significant_eigenvalues))

    print(f"Accuracy: {accuracy:.4f}")

plt.figure(figsize=(8, 5))
plt.plot(num_components_list, accuracies, marker='o')
plt.title('Зависимость Accuracy от количества главных компонент')
plt.xlabel('Количество отобранных компонент')
plt.ylabel('Accuracy')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# --- Порог: 0.85 * lambda_max = 4.8580 ---
# Число главных компонент: 3993
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f48a458df80>
# Traceback (most recent call last):
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x73fa1db81f80>
# Traceback (most recent call last):
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ...

# %%
for t in np.arange(1.25, 1.86, 0.05):
    lambda_limit = t * LAMBDA_MAX
    significant_mask = eigenvalues > lambda_limit
    significant_eigenvalues = eigenvalues[significant_mask]

    print(f"\n--- Порог: {t:.2f} * lambda_max = {lambda_limit:.4f} ---")
    print(f"Число главных компонент: {len(significant_eigenvalues)}")

    significant_components = Vt[significant_mask]
    Z = Y @ significant_components.T

    X_train, X_test, y_train, y_test = train_test_split(
        Z, 
        labels, 
        test_size=0.2, 
        random_state=42, 
        stratify=labels if len(np.unique(labels)) > 1 else None
    )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = np.mean(y_pred == y_test)
    accuracies.append(accuracy)
    num_components_list.append(len(significant_eigenvalues))

    print(f"Accuracy: {accuracy:.4f}")
# Out:
# --- Порог: 1.25 * lambda_max = 7.1440 ---
# Число главных компонент: 1443
# Exception ignored in: <function ResourceTracker.__del__ at 0x721f0c58df80>
# Traceback (most recent call last):
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x79cf13f95f80>
# Traceback (most recent call last):
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ...

# %%
plt.figure(figsize=(8, 5))
plt.plot(num_components_list, accuracies, marker='o')
plt.title('Зависимость Accuracy от количества главных компонент')
plt.xlabel('Количество отобранных компонент')
plt.ylabel('Accuracy')

plt.axvline(x=3022, color='red', linestyle='--', linewidth=1)

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Exception ignored in: <function ResourceTracker.__del__ at 0x766453981f80>
# Traceback (most recent call last):
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/home/fedor/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
